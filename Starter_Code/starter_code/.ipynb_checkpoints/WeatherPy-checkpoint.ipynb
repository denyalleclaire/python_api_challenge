# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_key}"
print(url+ "&q=Carver")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=eafea4372d72461a2cb19159ae4600a4&q=Carver

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_key}"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q= {city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather ['coord']['lat']
        city_lng = city_weather ['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | turkmenbasy
# Processing Record 3 of Set 1 | papatowai
# City not found. Skipping...
# Processing Record 4 of Set 1 | dhalie
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | siwa oasis
# City not found. Skipping...
# Processing Record 7 of Set 1 | salekhard
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | happy valley-goose bay
# Processing Record 10 of Set 1 | blackmans bay
# Processing Record 11 of Set 1 | bilibino
# Processing Record 12 of Set 1 | shiguai
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | yinchuan
# Processing Record 15 of Set 1 | margaret river
# Processing Record 16 of Set 1 | batyrevo
# Processing Record 17 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 19 of Set 1 | santa cruz de yojoa
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | masterton
# Processing Record 22 of Set 1 | kavarna
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | gisborne
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | puerto natales
# Processing Record 30 of Set 1 | saint-pierre
# Processing Record 31 of Set 1 | northam
# Processing Record 32 of Set 1 | port mathurin
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | kurumkan
# Processing Record 36 of Set 1 | trino
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | nagqu
# Processing Record 39 of Set 1 | comalapa
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | port hedland
# Processing Record 43 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 44 of Set 1 | kavieng
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | lazaro cardenas
# Processing Record 47 of Set 1 | enewetak
# Processing Record 48 of Set 1 | waitangi
# Processing Record 49 of Set 1 | rifle
# Processing Record 50 of Set 1 | ratnagiri
# Processing Record 0 of Set 2 | moram
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | bhisho
# Processing Record 3 of Set 2 | bamboo flat
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | orsa
# Processing Record 8 of Set 2 | khovd
# City not found. Skipping...
# Processing Record 9 of Set 2 | nar'yan-mar
# City not found. Skipping...
# Processing Record 10 of Set 2 | invercargill
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | tughyl
# Processing Record 15 of Set 2 | severo-yeniseyskiy
# Processing Record 16 of Set 2 | lianshan
# Processing Record 17 of Set 2 | aktau
# Processing Record 18 of Set 2 | crane
# Processing Record 19 of Set 2 | vrangel'
# City not found. Skipping...
# Processing Record 20 of Set 2 | puerto baquerizo moreno
# Processing Record 21 of Set 2 | nyala
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 2 | roma
# Processing Record 25 of Set 2 | west island
# Processing Record 26 of Set 2 | qapqal
# City not found. Skipping...
# Processing Record 27 of Set 2 | stary sacz
# Processing Record 28 of Set 2 | anadyr
# Processing Record 29 of Set 2 | sandersville
# Processing Record 30 of Set 2 | bela
# Processing Record 31 of Set 2 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 32 of Set 2 | al jawf
# Processing Record 33 of Set 2 | qaqortoq
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | alice springs
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | sisimiut
# Processing Record 38 of Set 2 | remire-montjoly
# Processing Record 39 of Set 2 | galle
# Processing Record 40 of Set 2 | pauini
# Processing Record 41 of Set 2 | kuqa
# Processing Record 42 of Set 2 | vilhena
# Processing Record 43 of Set 2 | doka
# Processing Record 44 of Set 2 | stepnoye
# Processing Record 45 of Set 2 | kogalym
# Processing Record 46 of Set 2 | igrim
# Processing Record 47 of Set 2 | qa'en
# City not found. Skipping...
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | olonkinbyen
# Processing Record 0 of Set 3 | hawaiian paradise park
# Processing Record 1 of Set 3 | kourou
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | nemuro
# Processing Record 4 of Set 3 | kodiak
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | uruacu
# Processing Record 7 of Set 3 | obidos
# Processing Record 8 of Set 3 | khandyga
# Processing Record 9 of Set 3 | san jose de jachal
# Processing Record 10 of Set 3 | naliya
# Processing Record 11 of Set 3 | gueltat zemmour
# City not found. Skipping...
# Processing Record 12 of Set 3 | san fernando
# Processing Record 13 of Set 3 | ketchikan
# Processing Record 14 of Set 3 | lihue
# Processing Record 15 of Set 3 | uturoa
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | isagarh
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | san rafael del yuma
# Processing Record 20 of Set 3 | brady
# Processing Record 21 of Set 3 | st. john's
# City not found. Skipping...
# Processing Record 22 of Set 3 | nguigmi
# Processing Record 23 of Set 3 | kolonia town
# Processing Record 24 of Set 3 | bridgewater
# Processing Record 25 of Set 3 | myaydo
# Processing Record 26 of Set 3 | bandarbeyla
# Processing Record 27 of Set 3 | klyuchi
# Processing Record 28 of Set 3 | ta`u
# City not found. Skipping...
# Processing Record 29 of Set 3 | demre
# Processing Record 30 of Set 3 | rio grande
# Processing Record 31 of Set 3 | iskateley
# Processing Record 32 of Set 3 | buncrana
# Processing Record 33 of Set 3 | zarinsk
# Processing Record 34 of Set 3 | usinsk
# Processing Record 35 of Set 3 | palikir - national government center
# Processing Record 36 of Set 3 | braunlingen
# Processing Record 37 of Set 3 | newman
# Processing Record 38 of Set 3 | alofi
# Processing Record 39 of Set 3 | aasiaat
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | haiku-pauwela
# Processing Record 43 of Set 3 | chernyshevsk
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | ta'izz
# City not found. Skipping...
# Processing Record 46 of Set 3 | nyrob
# Processing Record 47 of Set 3 | figuig (centre)
# Processing Record 48 of Set 3 | bulolo
# Processing Record 49 of Set 3 | dunedin
# Processing Record 0 of Set 4 | mtimbira
# Processing Record 1 of Set 4 | thakhek
# Processing Record 2 of Set 4 | bulgan
# Processing Record 3 of Set 4 | champerico
# Processing Record 4 of Set 4 | stanley
# Processing Record 5 of Set 4 | vilyuchinsk
# Processing Record 6 of Set 4 | loma de cabrera
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | cangas del narcea
# Processing Record 9 of Set 4 | funafuti
# Processing Record 10 of Set 4 | atafu village
# Processing Record 11 of Set 4 | praia da vitoria
# Processing Record 12 of Set 4 | holualoa
# Processing Record 13 of Set 4 | nampula
# Processing Record 14 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 15 of Set 4 | nantucket
# Processing Record 16 of Set 4 | kamphaeng phet
# Processing Record 17 of Set 4 | namibe
# Processing Record 18 of Set 4 | tolanaro
# City not found. Skipping...
# Processing Record 19 of Set 4 | jiazi
# Processing Record 20 of Set 4 | minot
# Processing Record 21 of Set 4 | rongelap
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | hovd
# Processing Record 24 of Set 4 | acarau
# Processing Record 25 of Set 4 | fort bragg
# Processing Record 26 of Set 4 | altamira
# Processing Record 27 of Set 4 | turiacu
# Processing Record 28 of Set 4 | kuala terengganu
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | torroella de montgri
# Processing Record 31 of Set 4 | catanzaro
# Processing Record 32 of Set 4 | west bay
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | kingston
# Processing Record 35 of Set 4 | urengoy
# Processing Record 36 of Set 4 | morehead city
# Processing Record 37 of Set 4 | yanbu
# City not found. Skipping...
# Processing Record 38 of Set 4 | lerwick
# Processing Record 39 of Set 4 | sao gabriel da cachoeira
# Processing Record 40 of Set 4 | vorgashor
# Processing Record 41 of Set 4 | antonio enes
# Processing Record 42 of Set 4 | itaueira
# Processing Record 43 of Set 4 | pochep
# Processing Record 44 of Set 4 | lautoka
# Processing Record 45 of Set 4 | fale old settlement
# Processing Record 46 of Set 4 | thames
# Processing Record 47 of Set 4 | utrik
# Processing Record 48 of Set 4 | essaouira
# Processing Record 49 of Set 4 | tamiahua
# Processing Record 0 of Set 5 | konarka
# Processing Record 1 of Set 5 | malabar
# Processing Record 2 of Set 5 | contai
# Processing Record 3 of Set 5 | nuuk
# Processing Record 4 of Set 5 | saint-francois
# Processing Record 5 of Set 5 | bodaybo
# Processing Record 6 of Set 5 | jerome
# Processing Record 7 of Set 5 | ghanzi
# Processing Record 8 of Set 5 | kerikeri
# Processing Record 9 of Set 5 | tazovsky
# City not found. Skipping...
# Processing Record 10 of Set 5 | north madison
# Processing Record 11 of Set 5 | horta
# Processing Record 12 of Set 5 | bel ombre
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | kushiro
# Processing Record 15 of Set 5 | chibougamau
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | huejutla de reyes
# Processing Record 18 of Set 5 | constantia
# Processing Record 19 of Set 5 | kapa'a
# City not found. Skipping...
# Processing Record 20 of Set 5 | amuntai
# Processing Record 21 of Set 5 | bonthe
# Processing Record 22 of Set 5 | dubrowna
# Processing Record 23 of Set 5 | new norfolk
# Processing Record 24 of Set 5 | cabedelo
# Processing Record 25 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 26 of Set 5 | selfoss
# Processing Record 27 of Set 5 | nogliki
# Processing Record 28 of Set 5 | egyek
# Processing Record 29 of Set 5 | senanga
# Processing Record 30 of Set 5 | odda
# Processing Record 31 of Set 5 | shkoder
# Processing Record 32 of Set 5 | tromso
# Processing Record 33 of Set 5 | axim
# Processing Record 34 of Set 5 | cururupu
# Processing Record 35 of Set 5 | nicoya
# Processing Record 36 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 37 of Set 5 | birao
# Processing Record 38 of Set 5 | acajutla
# Processing Record 39 of Set 5 | dampit
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | anna regina
# Processing Record 42 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 43 of Set 5 | kimbe
# Processing Record 44 of Set 5 | egilsstadir
# Processing Record 45 of Set 5 | riyadh
# Processing Record 46 of Set 5 | terrace
# Processing Record 47 of Set 5 | puerto santa
# Processing Record 48 of Set 5 | thunder bay
# Processing Record 49 of Set 5 | impfondo
# Processing Record 0 of Set 6 | naze
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | kitui
# Processing Record 3 of Set 6 | udachny
# City not found. Skipping...
# Processing Record 4 of Set 6 | dellys
# Processing Record 5 of Set 6 | murun-kuren
# Processing Record 6 of Set 6 | botou
# Processing Record 7 of Set 6 | tysmenytsya
# Processing Record 8 of Set 6 | tadine
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | nueva esperanza
# Processing Record 11 of Set 6 | hpa-an
# Processing Record 12 of Set 6 | labasa
# City not found. Skipping...
# Processing Record 13 of Set 6 | yen vinh
# Processing Record 14 of Set 6 | solnechnyy
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | al bardiyah
# City not found. Skipping...
# Processing Record 17 of Set 6 | cannonvale
# Processing Record 18 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | isawa
# Processing Record 21 of Set 6 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 22 of Set 6 | san antonio de pale
# City not found. Skipping...
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | touros
# Processing Record 25 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 26 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 27 of Set 6 | rikaze
# Processing Record 28 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 29 of Set 6 | vadso
# Processing Record 30 of Set 6 | tual
# Processing Record 31 of Set 6 | taksimo
# Processing Record 32 of Set 6 | mentor-on-the-lake
# Processing Record 33 of Set 6 | kapuskasing
# Processing Record 34 of Set 6 | yasuj
# Processing Record 35 of Set 6 | pader palwo
# Processing Record 36 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 6 | santa cruz
# Processing Record 38 of Set 6 | isangel
# Processing Record 39 of Set 6 | pokhara
# Processing Record 40 of Set 6 | hotan
# Processing Record 41 of Set 6 | puerto deseado
# Processing Record 42 of Set 6 | morant bay
# Processing Record 43 of Set 6 | katabu
# Processing Record 44 of Set 6 | paros
# Processing Record 45 of Set 6 | la passe
# City not found. Skipping...
# Processing Record 46 of Set 6 | pocatello
# Processing Record 47 of Set 6 | bakani
# Processing Record 48 of Set 6 | yakeshi
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 0 of Set 7 | sarmiento
# Processing Record 1 of Set 7 | tchintabaraden
# City not found. Skipping...
# Processing Record 2 of Set 7 | trail
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | mili
# Processing Record 5 of Set 7 | georgetown
# Processing Record 6 of Set 7 | seaside
# Processing Record 7 of Set 7 | nanakuli
# Processing Record 8 of Set 7 | ust-nera
# Processing Record 9 of Set 7 | semera
# Processing Record 10 of Set 7 | kraksaan
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | pochinok
# Processing Record 13 of Set 7 | xilin hot
# Processing Record 14 of Set 7 | walvis bay
# Processing Record 15 of Set 7 | nanao
# Processing Record 16 of Set 7 | byron bay
# Processing Record 17 of Set 7 | dabhol
# Processing Record 18 of Set 7 | kyzyl
# Processing Record 19 of Set 7 | pawni
# City not found. Skipping...
# Processing Record 20 of Set 7 | albu kamal
# Processing Record 21 of Set 7 | markovo
# Processing Record 22 of Set 7 | whitehorse
# Processing Record 23 of Set 7 | kolonia
# Processing Record 24 of Set 7 | korla
# Processing Record 25 of Set 7 | istaravshan
# Processing Record 26 of Set 7 | amga
# Processing Record 27 of Set 7 | numan
# Processing Record 28 of Set 7 | crucecita
# City not found. Skipping...
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | chonchi
# Processing Record 31 of Set 7 | santana
# Processing Record 32 of Set 7 | erenhot
# City not found. Skipping...
# Processing Record 33 of Set 7 | colonia
# Processing Record 34 of Set 7 | dabat
# Processing Record 35 of Set 7 | at taj
# Processing Record 36 of Set 7 | kirensk
# Processing Record 37 of Set 7 | nadi
# Processing Record 38 of Set 7 | pama
# Processing Record 39 of Set 7 | hithadhoo
# Processing Record 40 of Set 7 | fedorovskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | suva
# Processing Record 42 of Set 7 | sona
# Processing Record 43 of Set 7 | greymouth
# Processing Record 44 of Set 7 | zhezqazghan
# Processing Record 45 of Set 7 | huarmey
# Processing Record 46 of Set 7 | gassol
# Processing Record 47 of Set 7 | coronel suarez
# Processing Record 48 of Set 7 | little cayman
# City not found. Skipping...
# Processing Record 49 of Set 7 | ola
# Processing Record 0 of Set 8 | stromstad
# City not found. Skipping...
# Processing Record 1 of Set 8 | diamantino
# Processing Record 2 of Set 8 | lorengau
# Processing Record 3 of Set 8 | bratsk
# Processing Record 4 of Set 8 | sinop
# Processing Record 5 of Set 8 | port lincoln
# Processing Record 6 of Set 8 | dahab
# City not found. Skipping...
# Processing Record 7 of Set 8 | howard springs
# City not found. Skipping...
# Processing Record 8 of Set 8 | pionerskiy
# Processing Record 9 of Set 8 | santa rosalia
# Processing Record 10 of Set 8 | vorkuta
# Processing Record 11 of Set 8 | hamilton
# Processing Record 12 of Set 8 | tsumeb
# Processing Record 13 of Set 8 | twin falls
# Processing Record 14 of Set 8 | tondon
# Processing Record 15 of Set 8 | gunjur
# Processing Record 16 of Set 8 | polyarnyy
# Processing Record 17 of Set 8 | formosa
# Processing Record 18 of Set 8 | weno
# City not found. Skipping...
# Processing Record 19 of Set 8 | sainte-julie
# Processing Record 20 of Set 8 | zyryanovsk
# Processing Record 21 of Set 8 | pueblo
# Processing Record 22 of Set 8 | zag
# City not found. Skipping...
# Processing Record 23 of Set 8 | nova sintra
# City not found. Skipping...
# Processing Record 24 of Set 8 | yayva
# Processing Record 25 of Set 8 | pingliang
# Processing Record 26 of Set 8 | lensk
# Processing Record 27 of Set 8 | yorkton
# Processing Record 28 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 29 of Set 8 | chivhu
# Processing Record 30 of Set 8 | midvagur
# Processing Record 31 of Set 8 | gokwe
# Processing Record 32 of Set 8 | kishtwar
# Processing Record 33 of Set 8 | quzhou
# Processing Record 34 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 8 | cafayate
# Processing Record 36 of Set 8 | melekeok village
# Processing Record 37 of Set 8 | kiama
# Processing Record 38 of Set 8 | misratah
# Processing Record 39 of Set 8 | meadville
# Processing Record 40 of Set 8 | mount sterling
# Processing Record 41 of Set 8 | shiqian
# Processing Record 42 of Set 8 | sitangkai
# Processing Record 43 of Set 8 | akureyri
# Processing Record 44 of Set 8 | mahalapye
# Processing Record 45 of Set 8 | zvishavane
# Processing Record 46 of Set 8 | dagestanskiye ogni
# Processing Record 47 of Set 8 | viedma
# Processing Record 48 of Set 8 | ciudad bolivar
# Processing Record 49 of Set 8 | tidjikja
# Processing Record 0 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 1 of Set 9 | carnarvon
# Processing Record 2 of Set 9 | kishangarh
# Processing Record 3 of Set 9 | villa gesell
# Processing Record 4 of Set 9 | susuman
# Processing Record 5 of Set 9 | yola
# Processing Record 6 of Set 9 | ghat
# Processing Record 7 of Set 9 | roches noire
# Processing Record 8 of Set 9 | zomba
# Processing Record 9 of Set 9 | pamandzi
# Processing Record 10 of Set 9 | wanxian
# Processing Record 11 of Set 9 | barra de santo antonio
# Processing Record 12 of Set 9 | mirny
# City not found. Skipping...
# Processing Record 13 of Set 9 | berezovo
# Processing Record 14 of Set 9 | slave lake
# Processing Record 15 of Set 9 | howrah
# Processing Record 16 of Set 9 | marshall
# Processing Record 17 of Set 9 | egbe
# Processing Record 18 of Set 9 | bajos de haina
# Processing Record 19 of Set 9 | mossel bay
# Processing Record 20 of Set 9 | heroica matamoros
# Processing Record 21 of Set 9 | novoanninskiy
# Processing Record 22 of Set 9 | tamanrasset
# Processing Record 23 of Set 9 | badger
# Processing Record 24 of Set 9 | sinabang
# Processing Record 25 of Set 9 | port moresby
# Processing Record 26 of Set 9 | ardakan
# Processing Record 27 of Set 9 | shindand
# Processing Record 28 of Set 9 | dhone
# Processing Record 29 of Set 9 | calhoun
# Processing Record 30 of Set 9 | al kharijah
# Processing Record 31 of Set 9 | mogadishu
# Processing Record 32 of Set 9 | cabrobo
# Processing Record 33 of Set 9 | keflavik
# Processing Record 34 of Set 9 | bestobe
# Processing Record 35 of Set 9 | jiuquan
# City not found. Skipping...
# Processing Record 36 of Set 9 | cole harbour
# Processing Record 37 of Set 9 | zyryanskoye
# Processing Record 38 of Set 9 | port elizabeth
# Processing Record 39 of Set 9 | chatillon-sur-seine
# Processing Record 40 of Set 9 | krasnyy yar
# Processing Record 41 of Set 9 | camacupa
# Processing Record 42 of Set 9 | mthatha
# City not found. Skipping...
# Processing Record 43 of Set 9 | port macquarie
# Processing Record 44 of Set 9 | druskininkai
# Processing Record 45 of Set 9 | flying fish cove
# Processing Record 46 of Set 9 | aoulef
# Processing Record 47 of Set 9 | vuktyl
# Processing Record 48 of Set 9 | cockburn town
# Processing Record 49 of Set 9 | kandahar
# Processing Record 0 of Set 10 | khairpur
# Processing Record 1 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 2 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 3 of Set 10 | safotu
# Processing Record 4 of Set 10 | vangaindrano
# Processing Record 5 of Set 10 | minas de marcona
# Processing Record 6 of Set 10 | santa elena de uairen
# Processing Record 7 of Set 10 | maues
# Processing Record 8 of Set 10 | laojunmiao
# Processing Record 9 of Set 10 | dryden
# Processing Record 10 of Set 10 | kill devil hills
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | yokadouma
# Processing Record 13 of Set 10 | yallahs
# Processing Record 14 of Set 10 | freetown
# Processing Record 15 of Set 10 | angostura
# Processing Record 16 of Set 10 | kuta
# Processing Record 17 of Set 10 | meadow lake
# Processing Record 18 of Set 10 | tabas
# Processing Record 19 of Set 10 | puerto armuelles
# Processing Record 20 of Set 10 | astrakhan
# Processing Record 21 of Set 10 | tyukhtet
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | homer
# Processing Record 24 of Set 10 | stephenville
# Processing Record 25 of Set 10 | apomu
# Processing Record 26 of Set 10 | gornesti
# Processing Record 27 of Set 10 | holyhead
# Processing Record 28 of Set 10 | george town
# Processing Record 29 of Set 10 | mirnyy
# Processing Record 30 of Set 10 | ghormach
# Processing Record 31 of Set 10 | nema
# Processing Record 32 of Set 10 | tantou
# Processing Record 33 of Set 10 | koshekhabl'
# City not found. Skipping...
# Processing Record 34 of Set 10 | alta
# Processing Record 35 of Set 10 | poso
# Processing Record 36 of Set 10 | dahbed
# City not found. Skipping...
# Processing Record 37 of Set 10 | yumbe
# Processing Record 38 of Set 10 | koluszki
# Processing Record 39 of Set 10 | mushie
# Processing Record 40 of Set 10 | quellon
# City not found. Skipping...
# Processing Record 41 of Set 10 | callao
# Processing Record 42 of Set 10 | machico
# Processing Record 43 of Set 10 | khiri mat
# Processing Record 44 of Set 10 | afaahiti
# Processing Record 45 of Set 10 | kailua-kona
# Processing Record 46 of Set 10 | olyokminsk
# City not found. Skipping...
# Processing Record 47 of Set 10 | acapulco de juarez
# Processing Record 48 of Set 10 | saipan
# Processing Record 49 of Set 10 | upington
# Processing Record 0 of Set 11 | ornskoldsvik
# Processing Record 1 of Set 11 | bardai
# City not found. Skipping...
# Processing Record 2 of Set 11 | menaka
# Processing Record 3 of Set 11 | karak city
# Processing Record 4 of Set 11 | divnogorsk
# Processing Record 5 of Set 11 | mkushi
# Processing Record 6 of Set 11 | richards bay
# Processing Record 7 of Set 11 | terra santa
# Processing Record 8 of Set 11 | sretensk
# Processing Record 9 of Set 11 | sandnessjoen
# Processing Record 10 of Set 11 | ishigaki
# Processing Record 11 of Set 11 | cruz del eje
# Processing Record 12 of Set 11 | shohimardon
# Processing Record 13 of Set 11 | satsuma
# Processing Record 14 of Set 11 | vakfikebir
# Processing Record 15 of Set 11 | kepsut
# Processing Record 16 of Set 11 | les anglais
# Processing Record 17 of Set 11 | juneau
# Processing Record 18 of Set 11 | nalut
# Processing Record 19 of Set 11 | zemio
# Processing Record 20 of Set 11 | guanica
# Processing Record 21 of Set 11 | nova vicosa
# Processing Record 22 of Set 11 | ancud
# Processing Record 23 of Set 11 | hailar
# Processing Record 24 of Set 11 | el jadid
# City not found. Skipping...
# Processing Record 25 of Set 11 | kalinkavichy
# Processing Record 26 of Set 11 | isle of lewis
# City not found. Skipping...
# Processing Record 27 of Set 11 | sakaiminato
# Processing Record 28 of Set 11 | el granada
# Processing Record 29 of Set 11 | marka
# Processing Record 30 of Set 11 | mount pearl
# Processing Record 31 of Set 11 | netrakona
# Processing Record 32 of Set 11 | nizhniy kuranakh
# Processing Record 33 of Set 11 | maceio
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | mangrol
# Processing Record 36 of Set 11 | magadan
# Processing Record 37 of Set 11 | ambon
# Processing Record 38 of Set 11 | codrington
# Processing Record 39 of Set 11 | opuwo
# Processing Record 40 of Set 11 | darovskoy
# Processing Record 41 of Set 11 | tikhvin
# Processing Record 42 of Set 11 | padang
# Processing Record 43 of Set 11 | vila franca do campo
# Processing Record 44 of Set 11 | gracemere
# Processing Record 45 of Set 11 | coahuayana de hidalgo
# City not found. Skipping...
# Processing Record 46 of Set 11 | changling
# Processing Record 47 of Set 11 | pibor
# City not found. Skipping...
# Processing Record 48 of Set 11 | uva
# Processing Record 49 of Set 11 | valparaiso
# Processing Record 0 of Set 12 | parauapebas
# Processing Record 1 of Set 12 | jimenez
# Processing Record 2 of Set 12 | shoham
# City not found. Skipping...
# Processing Record 3 of Set 12 | kyren
# Processing Record 4 of Set 12 | ad dabbah
# Processing Record 5 of Set 12 | coronel moldes
# Processing Record 6 of Set 12 | maloye ganyushkino
# Processing Record 7 of Set 12 | marsaskala
# City not found. Skipping...
# Processing Record 8 of Set 12 | conduaga
# Processing Record 9 of Set 12 | malvan
# Processing Record 10 of Set 12 | antalaha
# Processing Record 11 of Set 12 | rundu
# Processing Record 12 of Set 12 | nehe
# Processing Record 13 of Set 12 | luwuk
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | deogarh
# Processing Record 16 of Set 12 | selma
# Processing Record 17 of Set 12 | ceelbuur
# Processing Record 18 of Set 12 | feijo
# Processing Record 19 of Set 12 | hadibu
# City not found. Skipping...
# Processing Record 20 of Set 12 | bamora
# Processing Record 21 of Set 12 | hun
# Processing Record 22 of Set 12 | bich'vinta
# City not found. Skipping...
# Processing Record 23 of Set 12 | nikolayevsk-on-amure
# City not found. Skipping...
# Processing Record 24 of Set 12 | argenton-sur-creuse
# Processing Record 25 of Set 12 | neustadt an der waldnaab
# Processing Record 26 of Set 12 | nadym
# Processing Record 27 of Set 12 | al bawiti
# Processing Record 28 of Set 12 | rio do sul
# Processing Record 29 of Set 12 | fort st. john
# Processing Record 30 of Set 12 | san luis de la loma
# City not found. Skipping...
# Processing Record 31 of Set 12 | mutuali
# Processing Record 32 of Set 12 | abra pampa
# Processing Record 33 of Set 12 | saint-joseph
# Processing Record 34 of Set 12 | chicholi
# Processing Record 35 of Set 12 | igarka
# Processing Record 36 of Set 12 | christchurch
# Processing Record 37 of Set 12 | wahpeton
# Processing Record 38 of Set 12 | le port
# Processing Record 39 of Set 12 | sharm el-sheikh
# City not found. Skipping...
# Processing Record 40 of Set 12 | nuku'alofa
# City not found. Skipping...
# Processing Record 41 of Set 12 | oyugis
# Processing Record 42 of Set 12 | sur
# Processing Record 43 of Set 12 | tan-tan
# Processing Record 44 of Set 12 | vernon
# Processing Record 45 of Set 12 | kavaratti
# Processing Record 46 of Set 12 | gustavsberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          523
# Lat           523
# Lng           523
# Max Temp      523
# Humidity      523
# Cloudiness    523
# Wind Speed    523
# Country       523
# Date          523
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     24.13        76         100
# 1        turkmenbasy  40.0222   52.9552     -4.57        86           0
# 2             dhalie  13.6957   44.7314     16.55        85          42
# 3  port-aux-francais -49.3500   70.2167      5.20        67          98
# 4          salekhard  66.5300   66.6019    -12.67        96          98
#
#    Wind Speed Country        Date
# 0        3.21      PN  1706215443
# 1        6.17      TM  1706215443
# 2        0.99      YE  1706215443
# 3       12.73      TF  1706215444
# 4        2.65      RU  1706215444

# %%
import os
output_directory = "output_data"
os.makedirs(output_directory, exist_ok=True)
city_data_df.to_csv(os.path.join(output_directory, "cities.csv"), index_label="City_ID")

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.13        76         100
# 1              turkmenbasy  40.0222   52.9552     -4.57        86           0
# 2                   dhalie  13.6957   44.7314     16.55        85          42
# 3        port-aux-francais -49.3500   70.2167      5.20        67          98
# 4                salekhard  66.5300   66.6019    -12.67        96          98
#
#          Wind Speed Country        Date
# City_ID
# 0              3.21      PN  1706215443
# 1              6.17      TM  1706215443
# 2              0.99      YE  1706215443
# 3             12.73      TF  1706215444
# 4              2.65      RU  1706215444

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Max Temp"], 
    edgecolor= "green", 
    linewidth = 1, 
    marker= "o", 
    alpha= 0.8, 
    label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel ("Latitude")
plt.ylabel ("Max Temp (C)")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Humidity"], 
    edgecolor= "red", 
    linewidth = 1, 
    marker= "o", 
    alpha= 0.8, 
    label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel ("Latitude")
plt.ylabel ("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Cloudiness"], 
    edgecolor= "purple", 
    linewidth = 1, 
    marker= "o", 
    alpha= 0.8, 
    label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Cloudiness {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel ("Latitude")
plt.ylabel ("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"], 
    edgecolor= "orange", 
    linewidth = 1, 
    marker= "o", 
    alpha= 0.8, 
    label= "Cities")

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Wind Speed {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel ("Latitude")
plt.ylabel ("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression (x_value, y_value, title, text_coord):
    
    (slope, intercept, rvalue, pvalue,stderr)= linregress(x_value, y_value)
    regress_value= x_value * slope + intercept
    line_eq= f"y= {round (slope,2 )} x + {round(intercept, 2)}"
    
    
    plt.scatter(x_value, y_value)
    plt.plot (x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color= "purple")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                   turkmenbasy  40.0222   52.9552     -4.57        86
# 2                        dhalie  13.6957   44.7314     16.55        85
# 4                     salekhard  66.5300   66.6019    -12.67        96
# 6        happy valley-goose bay  53.3168  -60.3315    -13.83        47
# 8                      bilibino  68.0546  166.4372    -37.58       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        6.17      TM  1706215443
# 2                42        0.99      YE  1706215443
# 4                98        2.65      RU  1706215444
# 6                 0        5.14      CA  1706215444
# 8                76        1.48      RU  1706215445

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df= city_data_df[city_data_df["Lat"]<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     24.13        76         100
# 3        port-aux-francais -49.3500   70.2167      5.20        67          98
# 5                grytviken -54.2811  -36.5092      3.62        78          76
# 7            blackmans bay -43.0167  147.3167     15.41        59          33
# 12          margaret river -33.9500  115.0667     11.35        83           3
#
#          Wind Speed Country        Date
# City_ID
# 0              3.21      PN  1706215443
# 3             12.73      TF  1706215444
# 5              6.13      GS  1706215444
# 7              0.89      AU  1706215444
# 12             3.79      AU  1706215445

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values= northern_hemi_df["Lat"]
y_values=northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6,-10))
# Out:
# The r-value is 0.6893714104284955

# %%
# Linear regression on Southern Hemisphere
x_values= southern_hemi_df["Lat"]
y_values=southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55,5))
# Out:
# The r-value is 0.19701514295200748

# %% [markdown]
# **Discussion about the linear relationship:

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values= northern_hemi_df["Lat"]
y_values=northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50,20))
# Out:
# The r-value is 0.3010313339924945

# %%
# Southern Hemisphere
x_values= southern_hemi_df["Lat"]
y_values=southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-55,5))
# Out:
# The r-value is 0.1710290148192084

# %% [markdown]
# **Discussion about the linear relationship:

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values= northern_hemi_df["Lat"]
y_values=northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (50,50))
# Out:
# The r-value is 0.15195807017051716

# %%
# Southern Hemisphere
x_values= southern_hemi_df["Lat"]
y_values=southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (55,55))
# Out:
# The r-value is 0.08105925988967234

# %% [markdown]
# **Discussion about the linear relationship:

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values= northern_hemi_df["Lat"]
y_values=northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,15))
# Out:
# The r-value is 0.0020582941977726546

# %%
# Southern Hemisphere
x_values= southern_hemi_df["Lat"]
y_values=southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-55,10))
# Out:
# The r-value is 0.16459011363227796

# %% [markdown]
# **Discussion about the linear relationship:
